# %% [markdown]
# # LGMVIP August Data Science Internship task 2

# %% [markdown]
# Image To Sketch With python _ (Uday Dogiparthi)

# %% [markdown]
# # Importing Libraries

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the Image

# %%
img = cv2.imread(r"C:\Users\91728\Desktop\LGM\Task 2 (Sketch)\baby-groot-hd-4k-superheroes-wallpaper-preview.jpg")

# %%
image=cv2.imread(r"C:\Users\91728\Desktop\LGM\Task 2 (Sketch)\baby-groot-hd-4k-superheroes-wallpaper-preview.jpg")
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(image)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %% [markdown]
# # Converting Original Image into Grayscale

# %%
gray_img=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(gray_img)
plt.axis("off")
plt.title("Gray-scale Image")
plt.show()

# %% [markdown]
# # Inverting the Grayscale Image

# %%
inv_grayImg = 255 - grayImg

# %%
import cv2
import matplotlib.pyplot as plt
img_path =r"C:\Users\91728\Desktop\LGM\Task 2 (Sketch)\baby-groot-hd-4k-superheroes-wallpaper-preview.jpg"
gray_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

if gray_img is not None:
    invt_img = cv2.bitwise_not(gray_img)  
    plt.figure(figsize=(8, 8))
    plt.imshow(invt_img, cmap="gray")
    plt.axis("off")
    plt.title("Inverted Gray-scale Image")
    plt.show()
else:
    print("Failed to load the image.")

# %% [markdown]
# # Blur the Image

# %%
blur_img = cv2.GaussianBlur(inv_grayImg, (35,35), 0)

# %%
display(Image.fromarray(blur_img))
# Out:
# <PIL.Image.Image image mode=L size=728x410>

# %%
img_smoothing = cv2.GaussianBlur(invt_img, (21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(8,8))
plt.imshow(img_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.show()

# %%
def mix(grayImg, blur_img):
    return cv2.divide(grayImg, inv_blurImg, scale = 210.0)

# %%
final = cv2.divide(gray_img, 255 - img_smoothing, scale=255)
plt.figure(figsize=(8,8))
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()
